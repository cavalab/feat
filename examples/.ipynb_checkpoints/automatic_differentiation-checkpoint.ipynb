# %% [markdown]
# # Automatic differentiation: a backpropagation example for genetic programming
#
# The purpose of this notebook is to demonstrate how weights can be learned for programs made up of differentiable nodes. In this case we're concerned with stack-based representations of mathematical functions, such as
#
# [ x1 x2 + sin ] $\rightarrow sin(x1+x2)$
#
# or with embedded weights, $w_4 \cdot \sin( w_3 \cdot ( w_1 \cdot x_1 + w_2 \cdot x_2) ) $

# %%
# define node classes
# Deal with elements that aren't differentiable (keep executing branch but skip past that value)
class Variable():
    def __init__(self,loc=0):
        self.loc = loc
        self.name='x_'+str(loc)
        self.arity=0
        self.visits=0
                
    def evaluate(self,stack,X=None):
        stack.append(X[:,self.loc])
    
class Add():
    def __init__(self, W=None):
        self.name='+'
        self.arity=2
        self.visits=0
        
        # Technically have vulnerability to lists of non numbers
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0, 1.0]
            
    def evaluate(self,stack,X=None):
        stack.append(self.W[0]*stack.pop() + self.W[1]*stack.pop())
        
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
            
        if loc == 0: stack.append(self.W[0])
        else: stack.append(self.W[1])
        
    def update(self,derivatives,fwd_stack,n):
        update_value = 1
        for d in derivatives[:]: # Calculate the chain rule
            update_value *= d
        
        W = self.W[:] # don't want weight update to cascade and change gradient for other weights
        d_w = fwd_stack[-1]
        self.W[0] = W[0] - n/update_value.size * sum(d_w * update_value)
        value = W[1] - n/update_value.size * sum(d_w * update_value)
        # print("Add updating W0 with", value, ' to value: ', self.W[0])
        d_w = fwd_stack[-2]
        self.W[1] = W[1] - n/update_value.size * sum(d_w * update_value)
        value = n/update_value.size * sum(d_w * update_value)
        # print("Add updating W1 with", value, ' to value: ', self.W[1])
        
        
class Subtract():
    def __init__(self,W=None):
        self.name='-'
        self.arity=2
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0, 1.0]
        
    def evaluate(self,stack,X=None):
        stack.append(self.W[0]*stack.pop() - self.W[1]*stack.pop())
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
            
        if loc == 0: stack.append(self.W[0])
        else: stack.append(- self.W[1])
        
    def update(self,derivatives,fwd_stack,n):
        update_value = 1
        for d in derivatives:
            update_value *= d
            
        W = self.W[:]
        d_w = fwd_stack[-1]
        self.W[0] = W[0] - n/update_value.size * sum(d_w * update_value)
        value = W[1] - n/update_value.size * sum(d_w * update_value)
        # print("Subtract updating W0 with", value, ' to value: ', self.W[0])
        d_w = - fwd_stack[-2]
        self.W[1] = W[1] - n/update_value.size * sum(d_w * update_value)
        value = n/update_value.size * sum(d_w * update_value)
        # print("Subtract updating W1 with", value, ' to value: ', self.W[1])
        
class Multiply():
    def __init__(self,W=None):
        self.name='*'
        self.arity=2
        self.error=0
        self.visits=0
        
        if isinstance(W, list) and len(W) == self.arity - 1: self.W = W
        else: self.W = [1.0, 1.0]
            
    def evaluate(self,stack,X=None):
        stack.append(self.W[0] * stack.pop() * self.W[1] * stack.pop())
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
        
        if loc == 0:
            stack.append(self.W[0] * self.W[1] * fwd_stack[-2]) 
        elif loc == 1:
            stack.append(self.W[0] * self.W[1] * fwd_stack[-1]) 
        
    def update(self,derivatives,fwd_stack,n):
        update_value = 1
        for d in derivatives:
            update_value *= d
        
        W = self.W[:]
        d_w = fwd_stack[-1] * W[1] * fwd_stack[-2]
        self.W[0] = W[0] - n/update_value.size * sum(d_w * update_value)
        d_w = fwd_stack[-1] * W[0] * fwd_stack[-2]
        self.W[1] = W[1] - n/update_value.size * sum(d_w * update_value)
        # print("Mult updating W1 to ", self.W[1])

class Divide():
    def __init__(self,W=None):
        self.name='/'
        self.arity=2
        self.error=0
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0, 1.0]
 
    def evaluate(self,stack,X=None):
        x2 = stack.pop()
        x1 = stack.pop()
        stack.append(self.W[1] * x1/(self.W[0] * x2))
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
        
        if loc==0: stack.append(self.W[1]/(self.W[0] * fwd_stack[-1]))
        else: stack.append(-self.W[1] * fwd_stack[-2]/(self.W[0] * fwd_stack[-1]**2))
        
    def update(self,derivatives,fwd_stack,n):            
        update_value = 1
        for d in derivatives:
            update_value *= d
            print("Gradient: ", d)
        x2 = fwd_stack[-1]
        x1 = fwd_stack[-2]
        W = self.W[:]
        d_w = -W[1] * x1/(x2 * W[0]**2)
        self.W[0] = W[0] - n/update_value.size * sum(d_w * update_value)
        print("Divide updating W1 with", d_w, ' to: ', self.W[0])
        d_w = x1/(W[0] * x2)
        self.W[1] = W[1] - n/update_value.size * sum(d_w * update_value)
        print("Divide updating W2 with", d_w, ' to: ', self.W[1])
 
class Sin():
    def __init__(self,W=None):
        self.name='sin'
        self.arity=1
        self.error=0
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0]
        
    def evaluate(self,stack,X=None):
        stack.append(np.sin(self.W[0] * stack.pop()))
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
        stack.append(self.W[loc] * np.cos(self.W[loc] * fwd_stack[-1]))
        
    def update(self,derivatives,fwd_stack,n,loc=-1):
        update_value = 1
        for d in derivatives[:]:
            update_value *= d
            # print("Updating with ", d)
        d_w = fwd_stack[-1] * np.cos(self.W[loc] * fwd_stack[-1])
        self.W[loc] = self.W[loc] - n/update_value.size * sum(d_w * update_value)
        value = n/update_value.size * sum(d_w * update_value)
        print("Sin updating W with", value, ' to: ', self.W[0])
        
class Cos():
    def __init__(self,W=None):
        self.name='cos'
        self.arity=1
        self.error=0
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0]
            
    def evaluate(self,stack,X=None):
        stack.append(np.cos(self.W[0] * stack.pop()))
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
        stack.append(self.W[loc] * -np.sin(self.W[loc] * fwd_stack[-1])) 
        
    def update(self,derivatives,fwd_stack,n,loc=0):
        print("------------------------------------")
        update_value = 1
        for d in derivatives[:]:
            update_value *= d
            print("D: ", d)
        
        #print("Update value: ", update_value)
        d_w = fwd_stack[-1] * -np.sin(self.W[0] * fwd_stack[-1])
        print("Derivative: ", d_w)
        print(fwd_stack[-1])
        self.W[loc] = self.W[loc] - n/update_value.size * sum(d_w * update_value)
        value = n/update_value.size * sum(d_w * update_value)
        print("Cos update value: ", sum(d_w * update_value))
        print("Cos updating W with", value, ' to value: ', self.W[0])
        
class Logit():
    def __init__(self,W=None):
        self.name='logit'
        self.arity=1
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0]
            
    def evaluate(self,stack,X=None):
        stack.append(1/(1 + np.exp(-self.W[0] * stack.pop())))
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
            
        numerator = self.W[0] * np.exp(-self.W[0] * fwd_stack[-1])
        denom = (1 + np.exp(-self.W[0] * fwd_stack[-1]))**2
        stack.append(numerator/denom)
        
    def update(self,derivatives,fwd_stack,n):
        update_value = 1
        for d in derivatives:
            update_value *= d
                 
        numerator = fwd_stack[-1] * np.exp(-self.W[0] * fwd_stack[-1])
        denom = (1 + np.exp(-self.W[0] * fwd_stack[-1]))**2
        d_w = numerator/denom
        self.W[0] = self.W[0] - n/update_value.size * sum(d_w * update_value)
        value = n/update_value.size * sum(d_w * update_value)
        # print("Logit updating W0 with", (n/update_value.size * sum(d_w * update_value)), ' to value: ', self.W[0])
      
# How do we deal with multiple outputs in the context of the program?
class Softmax2(): # Vector operating node - takes in 2 inputs and outputs wrt 1st
    def __init__(self,W=None):
        self.name='softmax'
        self.arity=2
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0 for x in range(self.arity)]
            
    def evaluate(self,stack,X=None):
        values = [np.exp(self.W[i] * stack.pop()) for i in range(self.arity)]        
        stack.append(values[1]/sum(values))
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
        
        if loc == 0:
            numerator = self.W[0] * np.exp(self.W[0] * fwd_stack[-1] + self.W[1] * fwd_stack[-2])
            denom = (np.exp(self.W[0] * fwd_stack[-1]) + np.exp(self.W[1] * fwd_stack[-2]))**2
            stack.append(numerator/denom)
        elif loc == 1:
            numerator = self.W[1] * np.exp(self.W[0] * fwd_stack[-1] + self.W[1] * fwd_stack[-2])
            denom = (np.exp(self.W[0] * fwd_stack[-1]) + np.exp(self.W[1] * fwd_stack[-2]))**2
            stack.append(numerator/denom)
        
    def update(self,derivatives,fwd_stack,n):
        update_value = 1
        for d in derivatives:
            update_value *= d
        
        W = self.W[:]
        numerator = fwd_stack[-1] * np.exp(W[0] * fwd_stack[-1] + W[1] * fwd_stack[-2])
        denom = (np.exp(W[0] * fwd_stack[-1]) + np.exp(W[1] * fwd_stack[-2]))**2
        d_w = numerator/denom
        self.W[0] = W[0] - n/update_value.size * sum(d_w * update_value)
        numerator = W[1] * np.exp(W[0] * fwd_stack[-1] + W[1] * fwd_stack[-2])
        denom = (np.exp(W[0] * fwd_stack[-1]) + np.exp(W[1] * fwd_stack[-2]))**2
        d_w = numerator/denom
        self.W[1] = W[1] - n/update_value.size * sum(d_w * update_value)
        
class Tanh():
    def __init__(self,W=None):
        self.name='tanh'
        self.arity=1
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0]
            
    def evaluate(self,stack,X=None):
        z = self.W[0] * stack.pop()
        stack.append((np.exp(z) - np.exp(-z))/(np.exp(z) + np.exp(-z)))
    
    def derivative(self,stack,fwd_stack,loc=0):
        if loc > self.arity: loc = 0
        
        numerator = 4 * self.W[0] * np.exp(2 * self.W[0] * fwd_stack[-1])
        denom = (np.exp(2 * self.W[0] * fwd_stack[-1]) + 1)**2
        stack.append(numerator/denom) # Might be an error from this statement
        # stack.append(self.W[0] * (1/np.arccosh(self.W[0] * fwd_stack[-1]))**2)
        
    def update(self,derivatives,fwd_stack,n):
        update_value = 1
        for d in derivatives:
            update_value *= d
        
        numerator = 4 * fwd_stack[-1] * np.exp(2 * self.W[0] * fwd_stack[-1])
        denom = (np.exp(2 * self.W[0] * fwd_stack[-1]) + 1)**2
        d_w = numerator/denom
        
        self.W[0] = self.W[0] - n/update_value.size * sum(d_w * update_value)
       #  print("Tanh updating to: ", self.W[0])
        
class Bias():
    def __init__(self,W=None):
        self.name='tanh'
        self.arity=1
        self.visits=0
        if isinstance(W, list) and len(W) == self.arity: self.W = W
        else: self.W = [1.0]
            
    def evaluate(self,stack,X=None):
        stack.append(self.W)
    
    def derivative(self,stack,fwd_stack,loc=0):
        stack.append(1);
        
    def update(self,derivatives,fwd_stack,n):
        update_value = 1
        for d in derivatives:
            update_value *= d
        
        self.W[0] = self.W[0] - n/update_value.size * sum(update_value)
        print("Bias updating to: ", self.W[0])

# %%
# Cost Functions
class CostSquaredDifference():
    def __init__(self,labels=None):
        self.visits=0
        self.arity=2
        self.name="Squared Error Cost"
        try: 
            _ = labels.shape
            self.arity=1
            self.labels=labels
        except:
            self.labels=labels
        
    def set_labels(self, labels):
        try: 
            _ = labels.shape
            self.arity=1
        except:
            self.labels=None
            self.arity=2
    
    def evaluate(self,Y_hat,Y=None,loc=0):
        try: 
            result = (Y_hat - Y)**2
        except:
            result = (Y_hat - self.labels)**2
            
        return result
    
    def derivative(self,Y_hat,Y=None):
        print("Cost function derivative pred: ", Y_hat)
        try: 
            print("Cost function derivative label: ", Y)
            result = 2*(Y_hat - Y)
        except:
            print("Cost function derivative label: ", self.labels)
            result = 2*(Y_hat - self.labels)
        return result
    
    def update(self,derivative,fwd_stack,n,loc):
        pass

# %%
import copy

class Auto_backprop():
    def __init__(self, program, cost_fcn, X, labels, iters=1000, n=0.1):
        self.program = program    # Program to modify (stack)
        self.cost_fcn = cost_fcn  # Determines how error is calculated (expected args are y_hat, y)
        self.X = X                # Training data (list of values)
        self.labels = labels      # Training labels (list of values)
        self.iters = iters        # Iterations of learning (scalar)
        self.n = n                # Learning Rate (scalar)
        
    def start(self):
        # "Intialize" cost function
        self.cost_fcn.set_labels(self.labels)
        
        # Computes weights via backprop
        for x in range(self.iters):            
            fwd_stack = self.forward_prop()
            if (x % round(self.iters/4)) == 0 or x == self.iters - 1:
                print("Currently on iter: " + str(x))
                print("Error: " + str(np.mean(self.cost_fcn.evaluate(fwd_stack[-1]))))
            self.backprop(fwd_stack)
            
        print("Gradient Descent Complete ------------------------------")
        return self.program
        
    def forward_prop(self):
        # Computes the forward pass of the program as described by the stack
        execution_stack = []
        fwd_stack = []
        
        # Program stack itself is unchanging
        for p in self.program:
            p.visits=0 # Clear our values set by backprop
            
            # Keep track of what computations were needed for execution (for purpose of GD)
            for x in range(p.arity):
                fwd_stack.append(execution_stack[-(p.arity - x)])
                
            p.evaluate(execution_stack, self.X)

        # Add the final prediction to the stack
        fwd_stack.append(execution_stack.pop())
        
        return fwd_stack
    
    # Returns the node and derivative of the parent, returns None if not found
    def get_next_branch(self, executing, bp_program, gradients):
        # Every node should have an associated gradient
        if executing:
            n_derivatives = []
            while not n_derivatives:
                (node, n_derivatives) = executing.pop()
                gradients.pop()
                
                if not executing:
                    return None
            
            # Should now have the next parent node
            bp_program.append(node)
            gradients.append(n_derivatives.pop(0))
            executing.append((node, n_derivatives))
        return None
        
    def backprop(self, fwd_stack):
        # Prepare stacks
        gradients = [self.cost_fcn.derivative(fwd_stack[-1])]
        print("Gradients: ", gradients)
        fwd_stack.pop() # Value is not an input to any function, not needed for derivatives
        
        executing = []
        bp_program = copy.copy(self.program) # Using a counter approach would allow avoiding this
        
        while bp_program:
            node = bp_program.pop() 
            # print("Evaluating: ", node.name)
            n_derivatives = []
            if node.visits == 0 and node.arity > 0:
                # New implementation: Calculate all gradients and updates at same time
                # If have arity > 1 then store extra derivatives on executing stack in following manner:
                # Stack holds elements with form: (node, [list of derivatives])
                # Once all derivatives are calculated can throw input values away
                
                for i in range(node.arity):
                    node.derivative(n_derivatives, fwd_stack, node.arity - 1 - i) # Values need to be calculated before updates
                    
                node.update(gradients,fwd_stack,self.n) # Update all weights
                
                # Get rid of all input arguments
                for x in range(node.arity):
                    fwd_stack.pop()
                
                # Add the gradient for the first branch into the current executing gradients
                if n_derivatives:
                    gradients.append(n_derivatives.pop(0))
                # Keep track of all gradients currently on stack
                executing.append((node, n_derivatives))
            
            # Care about tree structure for backpropping gradients
            if node.arity == 0:
                # Clean up gradients and find the parent node
                self.get_next_branch(executing, bp_program, gradients)
            else:
                # Must be an operator
                node.visits += 1 # Consider moving to after
                
                if node.visits > node.arity:         
                    self.get_next_branch(executing, bp_program, gradients)

# %%
import numpy as np
import matplotlib.pyplot as plt
# X = np.random.rand(100,2)
data1 = np.asarray([1.0 * i for i in range(100)])
data2 = np.flip(data1, 0)
data1 = np.asarray([7.3, 6.7])
data2 = np.asarray([12.4, 13.2])
X = np.stack((data1, data2), -1)

# test weights
w1, w2, w3 = 0.35, 0.76, 0.89
ytest = np.cos(w1*np.sin(w2*X[:,0] + w3*X[:,1]))
ytest = np.asarray([9.0, 8.0])

def run_test(prog, Y, iters):
    stack = []
    for p in prog:
        p.evaluate(stack, X)
    yhat2 = np.array(stack[-1])
    
    cost_fcn = CostSquaredDifference(ytest)
    error = cost_fcn.evaluate(yhat2)
    print('Error before GD: ' + str(np.mean(error)))
    
#     h1 = plt.figure()
#     plt.plot(ytest,yhat2)
#     plt.title('Before GD')
#     plt.show()
    
    GD = Auto_backprop(prog, cost_fcn, X, ytest, iters,0.1)
    prog = GD.start()
    stack = []
    for p in prog:
        p.evaluate(stack, X)
    yhat3 = np.array(stack[-1])
    
#     h2 = plt.figure()
#     plt.plot(ytest,yhat3)
#     plt.title('After')
#     plt.show()

# h0 = plt.figure()
# plt.plot(ytest,ytest)
# plt.title('Target')
# plt.show()

# Testing suite
prog_set = [[Variable(loc=0), Variable(loc=1), Add(), Sin(), Cos()],
            [Variable(loc=0), Variable(loc=1), Divide()],
            [Variable(loc=0), Sin()], [Variable(loc=0), Cos()], 
            [Variable(loc=0), Logit()], [Variable(loc=0), Tanh()], # 3 - 4
            [Variable(loc=0), Variable(loc=1), Softmax2()], [Variable(loc=0), Variable(loc=1), Divide()],
            [Variable(loc=0), Variable(loc=1), Multiply()], [Variable(loc=0), Variable(loc=1), Subtract()],
            [Variable(loc=0), Variable(loc=1), Add()], # 9
            [Variable(loc=0), Variable(loc=1), Add(), Sin()],
            [Variable(loc=0), Variable(loc=1), Subtract(), Cos()],
            [Variable(loc=0), Variable(loc=1), Multiply(), Logit()],
            [Variable(loc=0), Variable(loc=1), Add(), Tanh()],
            [Variable(loc=0), Cos(), Variable(loc=1), Sin(), Add(), Logit()],
            [Variable(loc=0), Cos(), Tanh(), Sin(), Variable(loc=1), Sin(), Add(), Logit()],
           ]

# Attempt backpropagation
ytest = np.cos(w1*np.sin(w2*X[:,0] + w3*X[:,1]))
ytest = np.asarray([9.0, 8.0])
prog = prog_set[15]

run_test(prog_set[1],ytest,100) # [Variable(loc=0), Cos(), Tanh(), Sin(), Variable(loc=1), Sin(), Add(), Logit()]
#run_test(prog_set[-2],ytest,1000) # [Variable(loc=0), Cos(), Variable(loc=1), Sin(), Add(), Logit()]
#run_test(prog_set[-4],ytest,1000) # [Variable(loc=0), Variable(loc=1), Multiply(), Logit()]
#run_test(prog_set[0],ytest,1000)  # [Variable(loc=0), Variable(loc=1), Add(), Sin(), Cos()]
# Out:
# Error before GD: 63.44311295960266
# Currently on iter: 0
# Error: 63.44311295960266
# ('Cost function derivative pred: ', array([0.58870968, 0.50757576]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-16.82258065, -14.98484848])])
# ('Gradient: ', array([-16.82258065, -14.98484848]))
# ('Divide updating W1 with', array([-0.58870968, -0.50757576]), ' to: ', 0.12452190765855509)
# ('Divide updating W2 with', array([0.58870968, 0.50757576]), ' to: ', 1.875478092341445)
# ('Cost function derivative pred: ', array([8.86681005, 7.64481714]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-0.26637989, -0.71036573])])
# ('Gradient: ', array([-0.26637989, -0.71036573]))
# ('Divide updating W1 with', array([-71.20682794, -61.39335062]), ' to: ', -3.004468057664048)
# ('Divide updating W2 with', array([4.72775987, 4.07619645]), ' to: ', 2.0832266131679478)
# ('Cost function derivative pred: ', array([-0.40819727, -0.35194094]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.81639455, -16.70388189])])
# ('Gradient: ', array([-18.81639455, -16.70388189]))
# ('Divide updating W1 with', array([-0.13586341, -0.11713919]), ' to: ', -3.2301249900912343)
# ('Divide updating W2 with', array([-0.19594473, -0.16894031]), ' to: ', 1.7577800001194817)
# ('Cost function derivative pred: ', array([-0.32036596, -0.27621424]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.64073192, -16.55242848])])
# ('Gradient: ', array([-18.64073192, -16.55242848]))
# ('Divide updating W1 with', array([-0.09918067, -0.08551194]), ' to: ', -3.3933365138116356)
# ('Divide updating W2 with', array([-0.18225601, -0.15713812]), ' to: ', 1.457859861419359)
# ('Cost function derivative pred: ', array([-0.25292399, -0.21806689]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.50584798, -16.43613377])])
# ('Gradient: ', array([-18.50584798, -16.43613377]))
# ('Divide updating W1 with', array([-0.07453549, -0.06426327]), ' to: ', -3.515115614706058)
# ('Divide updating W2 with', array([-0.17348992, -0.14958014]), ' to: ', 1.174404996778343)
# ('Cost function derivative pred: ', array([-0.19668872, -0.16958176]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.39337744, -16.33916353])])
# ('Gradient: ', array([-18.39337744, -16.33916353]))
# ('Divide updating W1 with', array([-0.05595512, -0.04824358]), ' to: ', -3.6059887852319474)
# ('Divide updating W2 with', array([-0.16747946, -0.14439803]), ' to: ', 0.902412199106613)
# ('Cost function derivative pred: ', array([-0.1473268 , -0.12702273]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.2946536 , -16.25404547])])
# ('Gradient: ', array([-18.2946536 , -16.25404547]))
# ('Divide updating W1 with', array([-0.04085615, -0.03522549]), ' to: ', -3.671989075121913)
# ('Divide updating W2 with', array([-0.16325888, -0.14075911]), ' to: ', 0.6386787240927672)
# ('Cost function derivative pred: ', array([-0.10239582, -0.08828399]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.20479165, -16.17656797])])
# ('Gradient: ', array([-18.20479165, -16.17656797]))
# ('Divide updating W1 with', array([-0.02788566, -0.02404255]), ' to: ', -3.716818001491622)
# ('Divide updating W2 with', array([-0.16032446, -0.1382291 ]), ' to: ', 0.3809414272807536)
# ('Cost function derivative pred: ', array([-0.06033761, -0.05202209]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.12067521, -16.10404418])])
# ('Gradient: ', array([-18.12067521, -16.10404418]))
# ('Divide updating W1 with', array([-0.01623367, -0.0139964 ]), ' to: ', -3.7427961928947093)
# ('Divide updating W2 with', array([-0.15839077, -0.13656191]), ' to: ', 0.12747408942141436)
# ('Cost function derivative pred: ', array([-0.02005058, -0.01728728]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.04010116, -16.03457456])])
# ('Gradient: ', array([-18.04010116, -16.03457456]))
# ('Divide updating W1 with', array([-0.00535711, -0.00461881]), ' to: ', -3.7513313706313625)
# ('Divide updating W2 with', array([-0.15729141, -0.13561405]), ' to: ', -0.12312923619102922)
# ('Cost function derivative pred: ', array([0.01932311, 0.01666006]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.96135379, -15.96667987])])
# ('Gradient: ', array([-17.96135379, -15.96667987]))
# ('Divide updating W1 with', array([0.005151  , 0.00444111]), ' to: ', -3.7431599380857996)
# ('Divide updating W2 with', array([-0.15693353, -0.1353055 ]), ' to: ', -0.37208514787727043)
# ('Cost function derivative pred: ', array([0.05852011, 0.05045507]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.88295978, -15.89908986])])
# ('Gradient: ', array([-17.88295978, -15.89908986]))
# ('Divide updating W1 with', array([0.01563388, 0.01347927]), ' to: ', -3.7184655288899107)
# ('Divide updating W2 with', array([-0.15727612, -0.13560087]), ' to: ', -0.6205097993961168)
# ('Cost function derivative pred: ', array([0.09823948, 0.08470046]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.80352104, -15.83059908])])
# ('Gradient: ', array([-17.80352104, -15.83059908]))
# ('Divide updating W1 with', array([0.02641936, 0.02277834]), ' to: ', -3.6769179116189865)
# ('Divide updating W2 with', array([-0.1583206, -0.1365014]), ' to: ', -0.8694879505547223)
# ('Cost function derivative pred: ', array([0.13921333, 0.12002743]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.72157335, -15.75994514])])
# ('Gradient: ', array([-17.72157335, -15.75994514]))
# ('Divide updating W1 with', array([0.03786142, 0.03264349]), ' to: ', -3.6176467370763294)
# ('Divide updating W2 with', array([-0.16010955, -0.13804381]), ' to: ', -1.1201357521482367)
# ('Cost function derivative pred: ', array([0.18228279, 0.15716121]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.63543441, -15.68567757])])
# ('Gradient: ', array([-17.63543441, -15.68567757]))
# ('Divide updating W1 with', array([0.05038712, 0.04344294]), ' to: ', -3.539145202631124)
# ('Divide updating W2 with', array([-0.16273277, -0.14030551]), ' to: ', -1.3736682542548213)
# ('Cost function derivative pred: ', array([0.22849919, 0.19700822]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.54300163, -15.60598356])])
# ('Gradient: ', array([-17.54300163, -15.60598356]))
# ('Divide updating W1 with', array([0.06456338, 0.05566548]), ' to: ', -3.439077696935149)
# ('Divide updating W2 with', array([-0.16634234, -0.14341761]), ' to: ', -1.6314840927050531)
# ('Cost function derivative pred: ', array([0.27928141, 0.24079182]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.44143718, -15.51841636])])
# ('Gradient: ', array([-17.44143718, -15.51841636]))
# ('Divide updating W1 with', array([0.08120823, 0.07001639]), ' to: ', -3.3139311073832394)
# ('Divide updating W2 with', array([-0.17118243, -0.14759066]), ' to: ', -1.895286140729849)
# ('Cost function derivative pred: ', array([0.33669176, 0.29029007]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.32661648, -15.41941986])])
# ('Gradient: ', array([-17.32661648, -15.41941986]))
# ('Divide updating W1 with', array([0.1015989 , 0.08759689]), ' to: ', -3.1583781834378764)
# ('Divide updating W2 with', array([-0.17764693, -0.15316425]), ' to: ', -2.1672723397680844)
# ('Cost function derivative pred: ', array([0.40397132, 0.3482974 ]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.19205736, -15.30340521])])
# ('Gradient: ', array([-17.19205736, -15.30340521]))
# ('Divide updating W1 with', array([0.12790467, 0.11027729]), ' to: ', -2.9640500572655326)
# ('Divide updating W2 with', array([-0.1863962 , -0.16070772]), ' to: ', -2.4504678121916244)
# ('Cost function derivative pred: ', array([0.4867037 , 0.41962788]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.02659261, -15.16074423])])
# ('Gradient: ', array([-17.02659261, -15.16074423]))
# ('Divide updating W1 with', array([0.16420225, 0.14157247]), ' to: ', -2.7169426149300637)
# ('Divide updating W2 with', array([-0.19861664, -0.17124399]), ' to: ', -2.749365363492294)
# ('Cost function derivative pred: ', array([0.59573507, 0.51363293]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-16.80852986, -14.97273413])])
# ('Gradient: ', array([-16.80852986, -14.97273413]))
# ('Divide updating W1 with', array([0.21926671, 0.18904813]), ' to: ', -2.3911366894643704)
# ('Divide updating W2 with', array([-0.21668094, -0.18681873]), ' to: ', -3.0713291209647013)
# ('Cost function derivative pred: ', array([0.75617642, 0.65196281]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-16.48764716, -14.69607437])])
# ('Gradient: ', array([-16.48764716, -14.69607437]))
# ('Divide updating W1 with', array([0.3162414 , 0.27265811]), ' to: ', -1.9300826628995653)
# ('Divide updating W2 with', array([-0.24620495, -0.21227384]), ' to: ', -3.430275738316511)
# ('Cost function derivative pred: ', array([1.04629535, 0.90209857]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-15.90740929, -14.19580286])])
# ('Gradient: ', array([-15.90740929, -14.19580286]))
# ('Divide updating W1 with', array([0.54209873, 0.46738857]), ' to: ', -1.1671655495111384)
# ('Divide updating W2 with', array([-0.30501786, -0.26298136]), ' to: ', -3.8595395077950094)
# ('Cost function derivative pred: ', array([1.9467232 , 1.67843258]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-14.10655359, -12.64313483])])
# ('Gradient: ', array([-14.10655359, -12.64313483]))
# ('Divide updating W1 with', array([1.66790667, 1.43804157]), ' to: ', 0.9183228672451447)
# ('Divide updating W2 with', array([-0.50439261, -0.43487897]), ' to: ', -4.490213252428625)
# ('Cost function derivative pred: ', array([-2.87854315, -2.48183234]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-23.75708629, -20.96366469])])
# ('Gradient: ', array([-23.75708629, -20.96366469]))
# ('Divide updating W1 with', array([3.13456547, 2.70257056]), ' to: ', 7.474519127733356)
# ('Divide updating W2 with', array([0.64107048, 0.55272037]), ' to: ', -3.149362693739234)
# Currently on iter: 25
# Error: 76.4970130603736
# ('Cost function derivative pred: ', array([-0.24805078, -0.21386528]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.49610156, -16.42773057])])
# ('Gradient: ', array([-18.49610156, -16.42773057]))
# ('Divide updating W1 with', array([0.03318619, 0.02861258]), ' to: ', 7.5287118693072985)
# ('Divide updating W2 with', array([0.07876221, 0.06790748]), ' to: ', -3.0207447088104145)
# ('Cost function derivative pred: ', array([-0.23620796, -0.2036546 ]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.47241591, -16.40730919])])
# ('Gradient: ', array([-18.47241591, -16.40730919]))
# ('Divide updating W1 with', array([0.03137429, 0.02705039]), ' to: ', 7.579881018084255)
# ('Divide updating W2 with', array([0.07819527, 0.06741867]), ' to: ', -2.893213978849744)
# ('Cost function derivative pred: ', array([-0.22470842, -0.19373989]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.44941683, -16.38747977])])
# ('Gradient: ', array([-18.44941683, -16.38747977]))
# ('Divide updating W1 with', array([0.02964538, 0.02555975]), ' to: ', 7.628171008980649)
# ('Divide updating W2 with', array([0.0776674 , 0.06696355]), ' to: ', -2.766699870997769)
# ('Cost function derivative pred: ', array([-0.21352209, -0.18409522]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.42704417, -16.36819043])])
# ('Gradient: ', array([-18.42704417, -16.36819043]))
# ('Divide updating W1 with', array([0.02799126, 0.0241336 ]), ' to: ', 7.673711981035246)
# ('Divide updating W2 with', array([0.07717573, 0.06653964]), ' to: ', -2.6411371649054782)
# ('Cost function derivative pred: ', array([-0.20262202, -0.17469736]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.40524404, -16.34939471])])
# ('Gradient: ', array([-18.40524404, -16.34939471]))
# ('Divide updating W1 with', array([0.02640469, 0.02276569]), ' to: ', 7.716621486524472)
# ('Divide updating W2 with', array([0.07671772, 0.06614475]), ' to: ', -2.5164654171642886)
# ('Cost function derivative pred: ', array([-0.19198396, -0.1655254 ]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.38396792, -16.3310508 ])])
# ('Gradient: ', array([-18.38396792, -16.3310508 ]))
# ('Divide updating W1 with', array([0.02487928, 0.0214505 ]), ' to: ', 7.757005938671026)
# ('Divide updating W2 with', array([0.07629112, 0.06577694]), ' to: ', -2.392628415856803)
# ('Cost function derivative pred: ', array([-0.18158598, -0.15656043]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.36317195, -16.31312086])])
# ('Gradient: ', array([-18.36317195, -16.31312086]))
# ('Divide updating W1 with', array([0.02340929, 0.0201831 ]), ' to: ', 7.794961844439952)
# ('Divide updating W2 with', array([0.07589393, 0.06543449]), ' to: ', -2.2695737097829527)
# ('Cost function derivative pred: ', array([-0.17140815, -0.14778528]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.3428163 , -16.29557055])])
# ('Gradient: ', array([-18.3428163 , -16.29557055]))
# ('Divide updating W1 with', array([0.02198961, 0.01895908]), ' to: ', 7.8305768594209715)
# ('Divide updating W2 with', array([0.07552438, 0.06511587]), ' to: ', -2.147252199946311)
# ('Cost function derivative pred: ', array([-0.16143231, -0.13918427]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.32286463, -16.27836855])])
# ('Gradient: ', array([-18.32286463, -16.27836855]))
# ('Divide updating W1 with', array([0.02061564, 0.01777446]), ' to: ', 7.863930694462444)
# ('Divide updating W2 with', array([0.07518088, 0.06481971]), ' to: ', -2.025617783246108)
# ('Cost function derivative pred: ', array([-0.15164182, -0.13074308]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.30328365, -16.26148615])])
# ('Gradient: ', array([-18.30328365, -16.26148615]))
# ('Divide updating W1 with', array([0.01928321, 0.01662566]), ' to: ', 7.895095898009557)
# ('Divide updating W2 with', array([0.07486201, 0.06454479]), ' to: ', -1.9046270401748457)
# ('Cost function derivative pred: ', array([-0.14202137, -0.12244848]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.28404275, -16.24489697])])
# ('Gradient: ', array([-18.28404275, -16.24489697]))
# ('Divide updating W1 with', array([0.01798856, 0.01550944]), ' to: ', 7.924138533612622)
# ('Divide updating W2 with', array([0.0745665 , 0.06429001]), ' to: ', -1.7842389597892534)
# ('Cost function derivative pred: ', array([-0.13255684, -0.11428832]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.26511367, -16.22857663])])
# ('Gradient: ', array([-18.26511367, -16.22857663]))
# ('Divide updating W1 with', array([0.01672823, 0.01442281]), ' to: ', 7.951118768520639)
# ('Divide updating W2 with', array([0.07429321, 0.06405438]), ' to: ', -1.6644146963924984)
# ('Cost function derivative pred: ', array([-0.12323512, -0.10625128]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.24647023, -16.21250256])])
# ('Gradient: ', array([-18.24647023, -16.21250256]))
# ('Divide updating W1 with', array([0.01549909, 0.01336306]), ' to: ', 7.976091386444802)
# ('Divide updating W2 with', array([0.07404111, 0.06383702]), ' to: ', -1.5451173533047036)
# ('Cost function derivative pred: ', array([-0.11404402, -0.09832687]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.22808804, -16.19665374])])
# ('Gradient: ', array([-18.22808804, -16.19665374]))
# ('Divide updating W1 with', array([0.01429823, 0.0123277 ]), ' to: ', 7.999106235304715)
# ('Divide updating W2 with', array([0.07380929, 0.06363715]), ' to: ', -1.426311789857202)
# ('Cost function derivative pred: ', array([-0.10497217, -0.09050527]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.20994434, -16.18101054])])
# ('Gradient: ', array([-18.20994434, -16.18101054]))
# ('Divide updating W1 with', array([0.01312299, 0.01131442]), ' to: ', 8.02020861893452)
# ('Divide updating W2 with', array([0.07359693, 0.06345406]), ' to: ', -1.307964448361926)
# ('Cost function derivative pred: ', array([-0.09600889, -0.08277728]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.19201778, -16.16555456])])
# ('Gradient: ', array([-18.19201778, -16.16555456]))
# ('Divide updating W1 with', array([0.01197087, 0.01032109]), ' to: ', 8.039439640233617)
# ('Divide updating W2 with', array([0.07340329, 0.0632871 ]), ' to: ', -1.1900431983102902)
# ('Cost function derivative pred: ', array([-0.08714413, -0.07513423]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.17428825, -16.15026845])])
# ('Gradient: ', array([-18.17428825, -16.15026845]))
# ('Divide updating W1 with', array([0.01083958, 0.0093457 ]), ' to: ', 8.05683650202562)
# ('Divide updating W2 with', array([0.0732277 , 0.06313571]), ' to: ', -1.0725171954686468)
# ('Cost function derivative pred: ', array([-0.07836838, -0.06756793]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.15673677, -16.13513585])])
# ('Gradient: ', array([-18.15673677, -16.13513585]))
# ('Divide updating W1 with', array([0.00972694, 0.00838641]), ' to: ', 8.072432770884191)
# ('Divide updating W2 with', array([0.07306958, 0.06299939]), ' to: ', -0.9553567538775565)
# ('Cost function derivative pred: ', array([-0.06967265, -0.06007061]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.1393453 , -16.12014121])])
# ('Gradient: ', array([-18.1393453 , -16.12014121]))
# ('Divide updating W1 with', array([0.00863094, 0.00744145]), ' to: ', 8.086258608352225)
# ('Divide updating W2 with', array([0.07292841, 0.06287767]), ' to: ', -0.8385332290436264)
# ('Cost function derivative pred: ', array([-0.06104834, -0.05263487]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.12209667, -16.10526973])])
# ('Gradient: ', array([-18.12209667, -16.10526973]))
# ('Divide updating W1 with', array([0.00754964, 0.00650917]), ' to: ', 8.098340973287574)
# ('Divide updating W2 with', array([0.07280372, 0.06277016]), ' to: ', -0.7220189108464145)
# ('Cost function derivative pred: ', array([-0.05248723, -0.04525363]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.10497447, -16.09050725])])
# ('Gradient: ', array([-18.10497447, -16.09050725]))
# ('Divide updating W1 with', array([0.00648123, 0.00558801]), ' to: ', 8.108703798487396)
# ('Divide updating W2 with', array([0.0726951 , 0.06267651]), ' to: ', -0.605786924877578)
# ('Cost function derivative pred: ', array([-0.04398146, -0.03792009]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.08796292, -16.07584017])])
# ('Gradient: ', array([-18.08796292, -16.07584017]))
# ('Divide updating W1 with', array([0.00542398, 0.00467647]), ' to: ', 8.117368144252854)
# ('Divide updating W2 with', array([0.07260219, 0.06259641]), ' to: ', -0.48981114109191554)
# ('Cost function derivative pred: ', array([-0.03552341, -0.03062769]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.07104681, -16.06125539])])
# ('Gradient: ', array([-18.07104681, -16.06125539]))
# ('Divide updating W1 with', array([0.00437622, 0.00377311]), ' to: ', 8.124352331139335)
# ('Divide updating W2 with', array([0.0725247, 0.0625296]), ' to: ', -0.3740660887857431)
# ('Cost function derivative pred: ', array([-0.02710571, -0.02337009]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.05421142, -16.04674019])])
# ('Gradient: ', array([-18.05421142, -16.04674019]))
# ('Divide updating W1 with', array([0.00333635, 0.00287655]), ' to: ', 8.129672053780686)
# ('Divide updating W2 with', array([0.07246235, 0.06247584]), ' to: ', -0.2585268770315656)
# ('Cost function derivative pred: ', array([-0.01872121, -0.01614112]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.03744241, -16.03228223])])
# ('Gradient: ', array([-18.03744241, -16.03228223]))
# ('Divide updating W1 with', array([0.00230282, 0.00198546]), ' to: ', 8.133340477368133)
# ('Divide updating W2 with', array([0.07241494, 0.06243496]), ' to: ', -0.1431691197928051)
# Currently on iter: 50
# Error: 72.66483758116988
# ('Cost function derivative pred: ', array([-0.01036291, -0.00893473]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.02072581, -16.01786945])])
# ('Gradient: ', array([-18.02072581, -16.01786945]))
# ('Divide updating W1 with', array([0.00127413, 0.00109853]), ' to: ', 8.135368318096237)
# ('Divide updating W2 with', array([0.07238227, 0.0624068 ]), ' to: ', -0.027968865021294073)
# ('Cost function derivative pred: ', array([-0.00202395, -0.00174501]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-18.00404789, -16.00349002])])
# ('Gradient: ', array([-18.00404789, -16.00349002]))
# ('Divide updating W1 with', array([0.00024878, 0.0002145 ]), ' to: ', 8.135763908651922)
# ('Divide updating W2 with', array([0.07236423, 0.06239124]), ' to: ', 0.08709747289436794)
# ('Cost function derivative pred: ', array([0.00630244, 0.00543386]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.98739513, -15.98913229])])
# ('Gradient: ', array([-17.98739513, -15.98913229]))
# ('Divide updating W1 with', array([-0.00077466, -0.0006679 ]), ' to: ', 8.134533249611925)
# ('Divide updating W2 with', array([0.07236071, 0.06238821]), ' to: ', 0.20205317790781246)
# ('Cost function derivative pred: ', array([0.01462292, 0.01260764]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.97075415, -15.97478471])])
# ('Gradient: ', array([-17.97075415, -15.97478471]))
# ('Divide updating W1 with', array([-0.00179764, -0.00154989]), ' to: ', 8.131680047423492)
# ('Divide updating W2 with', array([0.07237166, 0.06239765]), ' to: ', 0.3169212948560212)
# ('Cost function derivative pred: ', array([0.02294417, 0.01978208]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.95411166, -15.96043583])])
# ('Gradient: ', array([-17.95411166, -15.96043583]))
# ('Divide updating W1 with', array([-0.00282158, -0.00243272]), ' to: ', 8.127205739468181)
# ('Divide updating W2 with', array([0.07239705, 0.06241954]), ' to: ', 0.4317246902629456)
# ('Cost function derivative pred: ', array([0.0312728 , 0.02696289]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.93745439, -15.94607421])])
# ('Gradient: ', array([-17.93745439, -15.94607421]))
# ('Divide updating W1 with', array([-0.00384792, -0.00331761]), ' to: ', 8.121109506545091)
# ('Divide updating W2 with', array([0.07243691, 0.06245391]), ' to: ', 0.5464861118797885)
# ('Cost function derivative pred: ', array([0.03961548, 0.03415581]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.92076904, -15.93168837])])
# ('Gradient: ', array([-17.92076904, -15.93168837]))
# ('Divide updating W1 with', array([-0.00487809, -0.00420581]), ' to: ', 8.113388272954017)
# ('Divide updating W2 with', array([0.07249129, 0.06250079]), ' to: ', 0.6612282474173815)
# ('Cost function derivative pred: ', array([0.0479789 , 0.04136662]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.90404219, -15.91726677])])
# ('Gradient: ', array([-17.90404219, -15.91726677]))
# ('Divide updating W1 with', array([-0.00591355, -0.00509856]), ' to: ', 8.104036694207494)
# ('Divide updating W2 with', array([0.07256027, 0.06256027]), ' to: ', 0.7759737829143817)
# ('Cost function derivative pred: ', array([0.05636984, 0.04860115]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.88726031, -15.90279771])])
# ('Gradient: ', array([-17.88726031, -15.90279771]))
# ('Divide updating W1 with', array([-0.00695577, -0.00599715]), ' to: ', 8.093047132250193)
# ('Divide updating W2 with', array([0.072644  , 0.06263246]), ' to: ', 0.890745461180028)
# ('Cost function derivative pred: ', array([0.06479518, 0.05586534]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.87040963, -15.88826933])])
# ('Gradient: ', array([-17.87040963, -15.88826933]))
# ('Divide updating W1 with', array([-0.00800628, -0.00690288]), ' to: ', 8.08040961791142)
# ('Divide updating W2 with', array([0.07274265, 0.06271751]), ' to: ', 1.0055661407518222)
# ('Cost function derivative pred: ', array([0.07326194, 0.06316524]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.85347611, -15.87366952])])
# ('Gradient: ', array([-17.85347611, -15.87366952]))
# ('Divide updating W1 with', array([-0.00906661, -0.00781708]), ' to: ', 8.066111800158188)
# ('Divide updating W2 with', array([0.07285642, 0.0628156 ]), ' to: ', 1.1204588558167732)
# ('Cost function derivative pred: ', array([0.08177732, 0.07050705]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.83644537, -15.8589859 ])])
# ('Gradient: ', array([-17.83644537, -15.8589859 ]))
# ('Divide updating W1 with', array([-0.01013838, -0.00874114]), ' to: ', 8.050138881549186)
# ('Divide updating W2 with', array([0.07298556, 0.06292694]), ' to: ', 1.2354468775599874)
# ('Cost function derivative pred: ', array([0.09034869, 0.07789715]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.81930261, -15.8442057 ])])
# ('Gradient: ', array([-17.81930261, -15.8442057 ]))
# ('Divide updating W1 with', array([-0.01122325, -0.0096765 ]), ' to: ', 8.03247353910994)
# ('Divide updating W2 with', array([0.07313038, 0.0630518 ]), ' to: ', 1.3505537774267895)
# ('Cost function derivative pred: ', array([0.09898372, 0.08534212]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.80203257, -15.82931575])])
# ('Gradient: ', array([-17.80203257, -15.82931575]))
# ('Divide updating W1 with', array([-0.01232294, -0.01062464]), ' to: ', 8.0130958296526)
# ('Divide updating W2 with', array([0.07329121, 0.06319047]), ' to: ', 1.4658034928148032)
# ('Cost function derivative pred: ', array([0.1076903, 0.0928488]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.7846194, -15.8143024])])
# ('Gradient: ', array([-17.7846194, -15.8143024]))
# ('Divide updating W1 with', array([-0.01343929, -0.01158713]), ' to: ', 7.991983078345155)
# ('Divide updating W2 with', array([0.07346844, 0.06334328]), ' to: ', 1.5812203957513054)
# ('Cost function derivative pred: ', array([0.11647669, 0.10042428]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.76704662, -15.79915144])])
# ('Gradient: ', array([-17.76704662, -15.79915144]))
# ('Divide updating W1 with', array([-0.01457419, -0.01256563]), ' to: ', 7.969109749089025)
# ('Divide updating W2 with', array([0.07366253, 0.06351061]), ' to: ', 1.6968293651597404)
# ('Cost function derivative pred: ', array([0.1253515 , 0.10807599]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.749297  , -15.78384801])])
# ('Gradient: ', array([-17.749297  , -15.78384801]))
# ('Divide updating W1 with', array([-0.01572967, -0.01356187]), ' to: ', 7.944447294984372)
# ('Divide updating W2 with', array([0.07387396, 0.06369291]), ' to: ', 1.8126558633788727)
# ('Cost function derivative pred: ', array([0.13432376, 0.11581173]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.73135248, -15.76837654])])
# ('Gradient: ', array([-17.73135248, -15.76837654]))
# ('Divide updating W1 with', array([-0.01690788, -0.01457769]), ' to: ', 7.917963986841266)
# ('Divide updating W2 with', array([0.07410329, 0.06389063]), ' to: ', 1.9287260176703498)
# ('Cost function derivative pred: ', array([0.14340299, 0.12363968]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.71319403, -15.75272063])])
# ('Gradient: ', array([-17.71319403, -15.75272063]))
# ('Divide updating W1 with', array([-0.01811109, -0.01561509]), ' to: ', 7.889624717322805)
# ('Divide updating W2 with', array([0.07435114, 0.06410433]), ' to: ', 2.0450667075375373)
# ('Cost function derivative pred: ', array([0.15259922, 0.13156852]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.69480156, -15.73686295])])
# ('Gradient: ', array([-17.69480156, -15.73686295]))
# ('Divide updating W1 with', array([-0.01934176, -0.01667614]), ' to: ', 7.859390777871866)
# ('Divide updating W2 with', array([0.07461821, 0.06433459]), ' to: ', 2.161705658782992)
# ('Cost function derivative pred: ', array([0.16192312, 0.13960744]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.67615377, -15.72078513])])
# ('Gradient: ', array([-17.67615377, -15.72078513]))
# ('Divide updating W1 with', array([-0.0206025 , -0.01776314]), ' to: ', 7.827219605062433)
# ('Divide updating W2 with', array([0.07490526, 0.06458207]), ' to: ', 2.2786715453570814)
# ('Cost function derivative pred: ', array([0.17138602, 0.14776619]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.65722797, -15.70446762])])
# ('Gradient: ', array([-17.65722797, -15.70446762]))
# ('Divide updating W1 with', array([-0.02189616, -0.0188785 ]), ' to: ', 7.7930644924121575)
# ('Divide updating W2 with', array([0.07521313, 0.06484752]), ' to: ', 2.395994100200089)
# ('Cost function derivative pred: ', array([0.18100003, 0.15605524]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.63799994, -15.68788953])])
# ('Gradient: ', array([-17.63799994, -15.68788953]))
# ('Divide updating W1 with', array([-0.02322578, -0.02002489]), ' to: ', 7.756874262973364)
# ('Divide updating W2 with', array([0.07554277, 0.06513173]), ' to: ', 2.513704236459673)
# ('Cost function derivative pred: ', array([0.19077814, 0.16448576]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.61844373, -15.67102849])])
# ('Gradient: ', array([-17.61844373, -15.67102849]))
# ('Divide updating W1 with', array([-0.02459472, -0.02120516]), ' to: ', 7.718592897158348)
# ('Divide updating W2 with', array([0.07589522, 0.0654356 ]), ' to: ', 2.631834180681028)
# ('Cost function derivative pred: ', array([0.20073429, 0.17306979]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.59853142, -15.65386043])])
# ('Gradient: ', array([-17.59853142, -15.65386043]))
# ('Divide updating W1 with', array([-0.02600659, -0.02242245]), ' to: ', 7.6781591092174795)
# ('Divide updating W2 with', array([0.07627163, 0.06576014]), ' to: ', 2.750417619826435)
# Currently on iter: 75
# Error: 69.18625075802831
# ('Cost function derivative pred: ', array([0.21088355, 0.18182031]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.57823289, -15.63635937])])
# ('Gradient: ', array([-17.57823289, -15.63635937]))
# ('Divide updating W1 with', array([-0.02746538, -0.0236802 ]), ' to: ', 7.635505864532495)
# ('Divide updating W2 with', array([0.07667328, 0.06610644]), ' to: ', 2.869489864293936)
# ('Cost function derivative pred: ', array([0.22124224, 0.19075141]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.55751551, -15.61849718])])
# ('Gradient: ', array([-17.55751551, -15.61849718]))
# ('Divide updating W1 with', array([-0.02897545, -0.02498216]), ' to: ', 7.5905598283575)
# ('Divide updating W2 with', array([0.07710159, 0.06647572]), ' to: ', 2.9890880294842166)
# ('Cost function derivative pred: ', array([0.2318281 , 0.19987836]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.5363438 , -15.60024329])])
# ('Gradient: ', array([-17.5363438 , -15.60024329]))
# ('Divide updating W1 with', array([-0.03054163, -0.02633249]), ' to: ', 7.543240734766257)
# ('Divide updating W2 with', array([0.07755814, 0.06686934]), ' to: ', 3.1092512389263804)
# ('Cost function derivative pred: ', array([0.24266046, 0.20921784]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.51467907, -15.58156431])])
# ('Gradient: ', array([-17.51467907, -15.58156431]))
# ('Divide updating W1 with', array([-0.03216926, -0.0277358 ]), ' to: ', 7.493460662255157)
# ('Divide updating W2 with', array([0.07804466, 0.06728882]), ' to: ', 3.2300208525375997)
# ('Cost function derivative pred: ', array([0.25376053, 0.21878813]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.49247894, -15.56242373])])
# ('Gradient: ', array([-17.49247894, -15.56242373]))
# ('Divide updating W1 with', array([-0.03386426, -0.02919721]), ' to: ', 7.441123199588271)
# ('Divide updating W2 with', array([0.07856312, 0.06773583]), ' to: ', 3.3514407242850046)
# ('Cost function derivative pred: ', array([0.26515158, 0.22860931]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.46969684, -15.54278137])])
# ('Gradient: ', array([-17.46969684, -15.54278137]))
# ('Divide updating W1 with', array([-0.03563327, -0.03072242]), ' to: ', 7.386122481898229)
# ('Divide updating W2 with', array([0.0791157 , 0.06821225]), ' to: ', 3.473557494374886)
# ('Cost function derivative pred: ', array([0.27685933, 0.23870354]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.44628134, -15.52259292])])
# ('Gradient: ', array([-17.44628134, -15.52259292]))
# ('Divide updating W1 with', array([-0.03748372, -0.03231784]), ' to: ', 7.328342072568418)
# ('Divide updating W2 with', array([0.07970484, 0.06872019]), ' to: ', 3.59642092215903)
# ('Cost function derivative pred: ', array([0.28891225, 0.24909537]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.4221755 , -15.50180926])])
# ('Gradient: ', array([-17.4221755 , -15.50180926]))
# ('Divide updating W1 with', array([-0.03942396, -0.03399069]), ' to: ', 7.267653660743126)
# ('Divide updating W2 with', array([0.08033327, 0.06926202]), ' to: ', 3.7200842672798378)
# ('Cost function derivative pred: ', array([0.30134204, 0.25981213]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.39731591, -15.48037574])])
# ('Gradient: ', array([-17.39731591, -15.48037574]))
# ('Divide updating W1 with', array([-0.04146346, -0.03574911]), ' to: ', 7.203915537072859)
# ('Divide updating W2 with', array([0.08100409, 0.06984039]), ' to: ', 3.8446047282531133)
# ('Cost function derivative pred: ', array([0.31418414, 0.27088437]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.37163172, -15.45823125])])
# ('Gradient: ', array([-17.37163172, -15.45823125]))
# ('Divide updating W1 with', array([-0.04361297, -0.03760238]), ' to: ', 7.1369708009992445)
# ('Divide updating W2 with', array([0.08172079, 0.07045832]), ' to: ', 3.9700439498151923)
# ('Cost function derivative pred: ', array([0.32747833, 0.28234641]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.34504334, -15.43530719])])
# ('Gradient: ', array([-17.34504334, -15.43530719]))
# ('Divide updating W1 with', array([-0.04588478, -0.0395611 ]), ' to: ', 7.066645240827729)
# ('Divide updating W2 with', array([0.08248733, 0.07111921]), ' to: ', 4.09646861308155)
# ('Cost function derivative pred: ', array([0.34126953, 0.29423695]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.31746094, -15.4115261 ])])
# ('Gradient: ', array([-17.31746094, -15.4115261 ]))
# ('Divide updating W1 with', array([-0.048293  , -0.04163743]), ' to: ', 6.992744812069307)
# ('Divide updating W2 with', array([0.08330823, 0.07182698]), ' to: ', 4.223951126071681)
# ('Cost function derivative pred: ', array([0.3556087 , 0.30659995]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.2887826, -15.3868001])])
# ('Gradient: ', array([-17.2887826, -15.3868001]))
# ('Divide updating W1 with', array([-0.05085395, -0.04384544]), ' to: ', 6.915052618711488)
# ('Divide updating W2 with', array([0.08418864, 0.07258605]), ' to: ', 4.352570436718496)
# ('Cost function derivative pred: ', array([0.37055399, 0.31948553]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.25889202, -15.36102894])])
# ('Gradient: ', array([-17.25889202, -15.36102894]))
# ('Divide updating W1 with', array([-0.05358658, -0.04620146]), ' to: ', 6.833325274295296)
# ('Divide updating W2 with', array([0.08513452, 0.07340158]), ' to: ', 4.482412996475346)
# ('Cost function derivative pred: ', array([0.38617215, 0.33295125]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.2276557 , -15.33409751])])
# ('Gradient: ', array([-17.2276557 , -15.33409751]))
# ('Divide updating W1 with', array([-0.05651306, -0.04872463]), ' to: ', 6.747288482182302)
# ('Divide updating W2 with', array([0.08615274, 0.07427947]), ' to: ', 4.613573910591763)
# ('Cost function derivative pred: ', array([0.40254031, 0.34706361]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.19491938, -15.30587279])])
# ('Gradient: ', array([-17.19491938, -15.30587279]))
# ('Divide updating W1 with', array([-0.05965957, -0.05143749]), ' to: ', 6.6566316231824345)
# ('Divide updating W2 with', array([0.0872513 , 0.07522663]), ' to: ', 4.7461583218128185)
# ('Cost function derivative pred: ', array([0.41974823, 0.36189999]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.16050354, -15.27620002])])
# ('Gradient: ', array([-17.16050354, -15.27620002]))
# ('Divide updating W1 with', array([-0.06305715, -0.05436683]), ' to: ', 6.561001067832093)
# ('Divide updating W2 with', array([0.08843958, 0.07625114]), ' to: ', 4.880283088776858)
# ('Cost function derivative pred: ', array([0.43790115, 0.37755113]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.12419771, -15.24489773])])
# ('Gradient: ', array([-17.12419771, -15.24489773]))
# ('Divide updating W1 with', array([-0.06674304, -0.05754474]), ' to: ', 6.4599918310946265)
# ('Divide updating W2 with', array([0.08972864, 0.07736255]), ' to: ', 5.016078840383866)
# ('Cost function derivative pred: ', array([0.45712351, 0.39412434]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.08575298, -15.21175132])])
# ('Gradient: ', array([-17.08575298, -15.21175132]))
# ('Divide updating W1 with', array([-0.07076224, -0.06101004]), ' to: ', 6.353137045330514)
# ('Divide updating W2 with', array([0.09113164, 0.0785722 ]), ' to: ', 5.153692515350887)
# ('Cost function derivative pred: ', array([0.47756386, 0.41174767]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.04487228, -15.17650466])])
# ('Gradient: ', array([-17.04487228, -15.17650466]))
# ('Divide updating W1 with', array([-0.07516977, -0.06481014]), ' to: ', 6.239894521480107)
# ('Divide updating W2 with', array([0.09266441, 0.07989372]), ' to: ', 5.293290535845472)
# ('Cost function derivative pred: ', array([0.49940129, 0.43057554]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-17.00119742, -15.13884892])])
# ('Gradient: ', array([-17.00119742, -15.13884892]))
# ('Divide updating W1 with', array([-0.08003361, -0.06900366]), ' to: ', 6.1196293639768005)
# ('Divide updating W2 with', array([0.09434609, 0.08134364]), ' to: ', 5.43506282141112)
# ('Cost function derivative pred: ', array([0.52285423, 0.45079628]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-16.95429155, -15.09840745])])
# ('Gradient: ', array([-16.95429155, -15.09840745]))
# ('Divide updating W1 with', array([-0.08543887, -0.07366398]), ' to: ', 5.991591145304906)
# ('Divide updating W2 with', array([0.09620022, 0.08294224]), ' to: ', 5.579227933837985)
# ('Cost function derivative pred: ', array([0.54819252, 0.47264254]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-16.90361495, -15.05471492])])
# ('Gradient: ', array([-16.90361495, -15.05471492]))
# ('Divide updating W1 with', array([-0.09149365, -0.07888431]), ' to: ', 5.854883435871703)
# ('Divide updating W2 with', array([0.09825598, 0.08471469]), ' to: ', 5.726039770717256)
# ('Cost function derivative pred: ', array([0.57575442, 0.49640595]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-16.84849116, -15.0071881 ])])
# ('Gradient: ', array([-16.84849116, -15.0071881 ]))
# ('Divide updating W1 with', array([-0.09833747, -0.08478494]), ' to: ', 5.708422358246002)
# ('Divide updating W2 with', array([0.1005502 , 0.08669272]), ' to: ', 5.875796421339196)
# Currently on iter: 99
# Error: 63.1866777175498
# ('Cost function derivative pred: ', array([0.60597097, 0.52245816]))
# ('Cost function derivative label: ', None)
# ('Cost function derivative label: ', array([9., 8.]))
# ('Gradients: ', [array([-16.78805807, -14.95508369])])
# ('Gradient: ', array([-16.78805807, -14.95508369]))
# ('Divide updating W1 with', array([-0.10615384, -0.09152409]), ' to: ', 5.550878994261478)
# ('Divide updating W2 with', array([0.10313001, 0.08891699]), ' to: ', 6.028852108921642)
# Gradient Descent Complete ------------------------------
